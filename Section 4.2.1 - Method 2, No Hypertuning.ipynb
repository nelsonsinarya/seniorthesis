# %% [markdown]
# Note: ChatGPT was utilized for coding.
#
# “ChatGPT: State labeling and optimization,” ChatGPT: Array copy issue,” "ChatGPT: Overlay plot with shading,” "ChatGPT: K-means++ randomness issue,” "CVXPY Recurssion Error Fix." ChatGPT. [Online] Available:
# https://chatgpt.com/share/67c27bc7-9fc0-8005-bb81-8c4bbb17d290, https://chatgpt.com/share/67f176a4-e370-8005-a9f6-6907f2212a13, https://chatgpt.com/share/67f18721-6500-8005-b89d-4c7e05fb6db7, https://chatgpt.com/share/67da1ae1-0544-8005-a569-413cbf705e6c, https://chatgpt.com/share/67f63a04-d9b0-8005-ae4b-5cc7c5f53d62.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cvxpy as cp
from sklearn.cluster import KMeans
from xgboost import XGBClassifier

# %% [markdown]
# # **Read FRED GDP Data**

# %%
# Read GDP File
df_gdp = pd.read_csv('rGDP_JS.csv')
df_gdp['observation_date'] = pd.to_datetime(df_gdp.observation_date)
df_gdp.set_index('observation_date', inplace=True)

# %%
# Plot GDP
plt.figure(figsize=(12, 6))
plt.plot(df_gdp)
plt.xlabel('Year')
plt.ylabel('% Growth')
plt.title('US GDP Growth Overtime', fontsize='20')
# Out:
# Text(0.5, 1.0, 'US GDP Growth Overtime')

# %% [markdown]
# # **Step 1: Regime Identification**

# %% [markdown]
# ## **i. Feature Generation** *(Nystrup, et al. 2020)*

# %%
# Select Window Length
w1 = 6
w2 = 14

# %%
df_gdp_ft = df_gdp[max(w1, w2) - 1:]

# %% [markdown]
# *Absolute Change*

# %%
abs_change = []

for i in range(len(df_gdp_ft)):
  absChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 1] - df_gdp.rGDP[i + max(w1, w2) - 2])
  abs_change.append(absChange)

df_gdp_ft["AbsChange"] = abs_change
# Out:
# /tmp/ipykernel_662837/3168161603.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   absChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 1] - df_gdp.rGDP[i + max(w1, w2) - 2])
# /tmp/ipykernel_662837/3168161603.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["AbsChange"] = abs_change

# %% [markdown]
# *Previous Absolute Change*

# %%
prev_abs_change = []

for i in range(len(df_gdp_ft)):
  prevAbsChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 2] - df_gdp.rGDP[i + max(w1, w2) - 3])
  prev_abs_change.append(prevAbsChange)

df_gdp_ft["PrevAbs Change"] = prev_abs_change
# Out:
# /tmp/ipykernel_662837/1066985137.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prevAbsChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 2] - df_gdp.rGDP[i + max(w1, w2) - 3])
# /tmp/ipykernel_662837/1066985137.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["PrevAbs Change"] = prev_abs_change

# %% [markdown]
# **Features at w = 14**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)"] = centered_mean
df_gdp_ft["CenteredStd(14)"] = centered_std
# Out:
# /tmp/ipykernel_662837/603088380.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_662837/603088380.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)"] = centered_mean
# /tmp/ipykernel_662837/603088380.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)"] = left_mean
df_gdp_ft["LeftStd(14)"] = left_std
# Out:
# /tmp/ipykernel_662837/2429308197.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_662837/2429308197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)"] = left_mean
# /tmp/ipykernel_662837/2429308197.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)"] = right_mean
df_gdp_ft["RightStd(14)"] = right_std
# Out:
# /tmp/ipykernel_662837/1295607971.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_662837/1295607971.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)"] = right_mean
# /tmp/ipykernel_662837/1295607971.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)"] = right_std

# %% [markdown]
# **Features at w = 6**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)"] = centered_mean
df_gdp_ft["CenteredStd(6)"] = centered_std
# Out:
# /tmp/ipykernel_662837/1041938135.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_662837/1041938135.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)"] = centered_mean
# /tmp/ipykernel_662837/1041938135.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)"] = left_mean
df_gdp_ft["LeftStd(6)"] = left_std
# Out:
# /tmp/ipykernel_662837/726827072.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_662837/726827072.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)"] = left_mean
# /tmp/ipykernel_662837/726827072.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)"] = right_mean
df_gdp_ft["RightStd(6)"] = right_std
# Out:
# /tmp/ipykernel_662837/3669477337.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_662837/3669477337.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)"] = right_mean
# /tmp/ipykernel_662837/3669477337.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)"] = right_std

# %% [markdown]
# **What we have now:** 15-dimensional feature vector for the rGDP return Time Series

# %%
df_gdp_ft
# Out:
#                   rGDP  AbsChange  PrevAbs Change  CenteredMean(14)  \
# observation_date
# 1950-07-01         3.9        0.8             0.8          1.028571
# 1950-10-01         1.9        2.0             0.8          1.185714
# 1951-01-01         1.4        0.5             2.0          1.300000
# 1951-04-01         1.7        0.3             0.5          1.307143
# 1951-07-01         2.1        0.4             0.3          1.350000
# ...                ...        ...             ...               ...
# 2023-04-01         0.6        0.1             0.1          0.564286
# 2023-07-01         1.1        0.5             0.1          0.742857
# 2023-10-01         0.8        0.3             0.5          1.364286
# 2024-01-01         0.4        0.4             0.3          0.835714
# 2024-04-01         0.7        0.3             0.4          0.807143
#
#                   CenteredStd(14)  LeftMean(14)  LeftStd(14)  RightMean(14)  \
# observation_date
# 1950-07-01               1.628070      0.714286     0.813157       1.342857
# 1950-10-01               1.598149      0.557143     1.062150       1.814286
# 1951-01-01               1.551497      0.542857     1.072856       2.057143
# 1951-04-01               1.553091      0.457143     1.006915       2.157143
# 1951-07-01               1.566046      0.128571     0.988092       2.571429
# ...                           ...           ...          ...            ...
# 2023-04-01               3.077710      0.500000     4.309458       0.628571
# 2023-07-01               3.030727      0.957143     4.253018       0.528571
# 2023-10-01               1.861108      2.042857     2.434782       0.685714
# 2024-01-01               0.540644      0.942857     0.722806       0.728571
# 2024-04-01               0.536476      0.885714     0.723935       0.728571
#
#                   RightStd(14)  CenteredMean(6)  CenteredStd(6)  LeftMean(6)  \
# observation_date
# 1950-07-01            2.107712         1.800000        1.928730    -0.033333
# 1950-10-01            1.786000         2.166667        1.688852     1.366667
# 1951-01-01            1.586422         2.233333        1.648905     2.066667
# 1951-04-01            1.537955         2.650000        1.029158     3.633333
# 1951-07-01            0.972059         2.350000        0.871302     2.966667
# ...                        ...              ...             ...          ...
# 2023-04-01            0.604068         0.433333        0.398609     0.166667
# 2023-07-01            0.436592         0.666667        0.298142     0.533333
# 2023-10-01            0.279942         0.783333        0.157233     0.733333
# 2024-01-01            0.197949         0.733333        0.213437     0.700000
# 2024-04-01            0.197949         0.716667        0.211476     0.800000
#
#                   LeftStd(6)  RightMean(6)  RightStd(6)
# observation_date
# 1950-07-01          0.758654      3.633333     0.377124
# 1950-10-01          1.936205      2.966667     0.821922
# 1951-01-01          2.053182      2.400000     1.080123
# 1951-04-01          0.377124      1.666667     0.205480
# 1951-07-01          0.821922      1.733333     0.286744
# ...                      ...           ...          ...
# 2023-04-01          0.410961      0.700000     0.081650
# 2023-07-01          0.309121      0.800000     0.216025
# 2023-10-01          0.047140      0.833333     0.205480
# 2024-01-01          0.081650      0.766667     0.286744
# 2024-04-01          0.216025      0.633333     0.169967
#
# [296 rows x 15 columns]

# %%
# Determine Training and Testing Period
df_gdp_ft_train = df_gdp_ft [:220]
df_gdp_ft_test = df_gdp_ft[220-1:-30]

# %% [markdown]
# ## **ii. Model Fitting** *(Nystrup, et al. 2020)*

# %% [markdown]
# CVXPY Citation: https://drive.google.com/file/d/1VyB1QPfnzWfribfMdIJNdSlcbFsUQuqu/view?usp=sharing
#
# K-Means Citation: https://scikit-learn.org/1.5/modules/generated/sklearn.cluster.KMeans.html

# %% [markdown]
# Utilizing K-Means++ *(Nystrup, et al. 2020)*

# %% [markdown]
# Statistical Jump Model Fitting

# %%
def JM (np_gdp_ft, lamda):

  # ---------------- K-Means Initialization ------------------

  kmeans = KMeans(n_clusters=2, random_state=0, init='k-means++', n_init="auto").fit(np_gdp_ft)
  kmeans_labels = kmeans.labels_
  s_hat_hold = kmeans_labels

  # ------------------------------------------------------------

  objectiveValuePrev = 0
  objectiveValueCurrent = 0
  objectiveValueDiff = 100000

  n = 0
  T = np_gdp_ft.shape[0]
  D = df_gdp_ft.shape[1]
  print("Objective Value Convergence per Iteration")

  while objectiveValueDiff > 10e-6:

    # ----------------- MODEL FITTING COMPONENT ------------------------
    #      (input: a state sequence s_hat_hold and series np_gdp_ft)

    # Declare Variables
    theta0 = cp.Variable(D)
    theta1 = cp.Variable(D)

    # Objective Function
    loss = 0
    for i in range(T):
      if (s_hat_hold[i] == 0):
        loss = (1/2) * cp.sum_squares(np_gdp_ft[i] - theta0) + loss
      if (s_hat_hold[i] == 1):
        loss = (1/2) *  cp.sum_squares(np_gdp_ft[i] - theta1) + loss
    objective = cp.Minimize(loss)

    # Solve Problem
    problem = cp.Problem(objective)
    problem.solve()

    # ----------------- STATE-SEQUENCE FITTING ------------------------
    #      (input: parameter vector theta_0 and theta_1)
      
    # Populate Loss Matrix L
    K = 2 # Number of States
    L = np.zeros((T,K))
    for i in range(T):
        L[i][0] = (1/2) * np.linalg.norm(np_gdp_ft[i] - theta0.value)**2
        L[i][1] = (1/2) * np.linalg.norm(np_gdp_ft[i] - theta1.value)**2

    # Begin Dynamic Programming
    V = np.zeros((T,K)) # starting from t=1, not t=0
    V[0][0] = L[0][0] # Initialization
    V[0][1] = L[0][1] # Initialization

    # Populate V Matrix for k = 0,1
    for i in range(T - 1):
      V[i + 1][0] = L[i + 1][0] + min(V[i][0], V[i][1] + lamda) # Check
      V[i + 1][1] = L[i + 1][1] + min(V[i][0] + lamda, V[i][1]) # Check

    # Compute Optimal Value and Optimal Final State
    objectiveValue = min(V[T-1][0], V[T-1][1])
    s_hat = np.zeros(T)
    s_hat[T-1] = np.argmin([V[T-1][0], V[T-1][1]])

    # Retrace State Sequence s_hat from Optimal Value
    for i in range(T-1):
        if (s_hat[T-1-i] == 0):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0],V[T-2-i][1] + lamda])
        if (s_hat[T-1-i] == 1):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0] + lamda,V[T-2-i][1]])

    # Calculating Convergence Improvement per Iteration
    if (n == 0):
      objectiveValuePrev = objectiveValue
    if (n > 0):
      objectiveValueCurrent = objectiveValue
      objectiveValueDiff = np.abs(objectiveValuePrev - objectiveValueCurrent)
      objectiveValuePrev = objectiveValueCurrent

    n = n + 1
    print(objectiveValueDiff)

    s_hat_hold = s_hat

  # ----------------- DEFINE RECESSIONARY REGIME ------------------------
    
  # Define s_t = 1 as the recessionary regime
  if (theta1.value[0] > theta0.value[0]):
      for i in range(len(s_hat_hold)):
          if (s_hat_hold[i] == 0):
              s_hat_hold[i] = 1
          else:
              s_hat_hold[i] = 0
      theta0_value = theta1.value.copy()
      theta1_value = theta0.value.copy()
    
  else:
      theta0_value = theta0.value.copy()
      theta1_value = theta1.value.copy()

  print('Total Iterations: ', n)
  print()
  return theta0_value, theta1_value, s_hat_hold, V

# %% [markdown]
# # **Step 2: GDP Forecast**

# %%
# -------------------- PARAMETER CONTROLS ------------------------
lamda = 0.1
n = 1 # Number of Quarters until Refit and Re-train

# %%
# ------------------ DATA AND VARIABLE PREP ----------------------

# Prepare Dataset to Fit Model
np_gdp_ft = df_gdp_ft_train.to_numpy()
T = np_gdp_ft.shape[0]
D = df_gdp_ft.shape[1]

# Prepare Dataset to Retrain JM
np_gdp_ft_retrain = df_gdp_ft_train.to_numpy()

# Prepare Dataset for Out-of-Sample Testing
data_test_x = df_gdp_ft_test.to_numpy() ## State Prediction
preds = np.zeros(len(data_test_x)-1) ## x_t(1) Prediction

# Store State Predictions
sPreds = np.zeros(len(data_test_x)-1)

# %%
# ------------------- START ITERATIONS ----------------------

count = 0

for i in range(len(data_test_x)-1):

  print(count)
  count = count + 1

  # -------- RE-FITTING JM MODEL (Yizhan Shu, et al.) -----------

  if (i%n == 0):
    theta0, theta1, s_new, V = JM(np_gdp_ft, lamda)

    if (i == 0):
      plt.plot(df_gdp_ft_train.index,s_new)
      plt.xlabel('Year')
      plt.ylabel('Recession')
      plt.title('Jump Model Optimal State Sequence for First Run')

  # ---------------- TRAINING PHASE {(x_t, s_t+1)} ----------------

  # Preparing Dataset to Train (Retrain every period; np_gdp_ft and s_new updates)
  data_train_x = np_gdp_ft[:len(np_gdp_ft)-1]
  data_train_s_t1 = s_new[1:]

  # Train with XGBClassifier
  bst = XGBClassifier()
  bst.fit(data_train_x, data_train_s_t1)

  # ---------------------- FORECASTING PHASE ----------------------

  sPred = bst.predict([data_test_x[i]])
  sPreds[i] = sPred[0]

  if (sPred[0] == 0):
    preds[i] = theta0[0]

  if (sPred[0] == 1):
    preds[i] = theta1[0]

  np_gdp_ft_retrain = np.vstack((np_gdp_ft_retrain, data_test_x[i]))
  np_gdp_ft = np_gdp_ft_retrain.copy()
# Out:
# 0
# Objective Value Convergence per Iteration
# 100000
# 0.04728436629761745
# 0.060622717537683
# 0.0
# Total Iterations:  4
#
# 1
# Objective Value Convergence per Iteration
# 100000
# 0.18185715873659092
# 0.248368259421909
# 0.041912541740146025
# 0.0
# Total Iterations:  5
#
# 2
# Objective Value Convergence per Iteration
# 100000
# 0.060100533765648834
# 0.0
# Total Iterations:  3
#
# 3
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 4
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 5
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 6
# Objective Value Convergence per Iteration
# 100000
# 0.059399210202570885
# 0.0
# Total Iterations:  3
#
# 7
# Objective Value Convergence per Iteration
# 100000
# 0.059213708599372694
# 0.0
# Total Iterations:  3
#
# 8
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 9
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 10
# Objective Value Convergence per Iteration
# 100000
# 0.04217863979891945
# 0.0
# Total Iterations:  3
#
# 11
# Objective Value Convergence per Iteration
# 100000
# 0.04207882760681514
# 0.0
# Total Iterations:  3
#
# 12
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 13
# Objective Value Convergence per Iteration
# 100000
# 0.08098143593952045
# 0.13739085475015145
# 0.0
# Total Iterations:  4
#
# 14
# Objective Value Convergence per Iteration
# 100000
# 0.05514152997596966
# 0.19581123667546763
# 0.09387882880986353
# 0.03764084134780887
# 0.0
# Total Iterations:  6
#
# 15
# Objective Value Convergence per Iteration
# 100000
# 0.025915448815055697
# 0.0
# Total Iterations:  3
#
# 16
# Objective Value Convergence per Iteration
# 100000
# 0.035092328339374035
# 0.0
# Total Iterations:  3
#
# 17
# Objective Value Convergence per Iteration
# 100000
# 0.06299939671515631
# 0.0
# Total Iterations:  3
#
# 18
# Objective Value Convergence per Iteration
# 100000
# 0.37457255980370974
# 0.3384128160817568
# 0.03595688916556128
# 0.0
# Total Iterations:  5
#
# 19
# Objective Value Convergence per Iteration
# 100000
# 0.15103395531770047
# 0.19580865791607494
# 0.15979920567508543
# 0.0
# Total Iterations:  5
#
# 20
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 21
# Objective Value Convergence per Iteration
# 100000
# 0.20880145464695943
# 0.14092631987705317
# 0.0
# Total Iterations:  4
#
# 22
# Objective Value Convergence per Iteration
# 100000
# 0.2178830321533951
# 0.14141488891056042
# 0.03701246839978012
# 0.018845151883795097
# 0.0
# Total Iterations:  6
#
# 23
# Objective Value Convergence per Iteration
# 100000
# 0.09970149419439167
# 0.03821117120975259
# 0.06888779845309045
# 0.030350865306786545
# 0.0
# Total Iterations:  6
#
# 24
# Objective Value Convergence per Iteration
# 100000
# 0.18552558558235432
# 0.0
# Total Iterations:  3
#
# 25
# Objective Value Convergence per Iteration
# 100000
# 0.11984131914329055
# 0.07340176829012535
# 0.12606263525839267
# 0.2902937051154595
# 0.26242644334985243
# 0.30942633230876027
# 0.1725931109656358
# 0.05140281001160929
# 0.0
# Total Iterations:  10
#
# 26
# Objective Value Convergence per Iteration
# 100000
# 0.0899342269774479
# 0.0
# Total Iterations:  3
#
# 27
# Objective Value Convergence per Iteration
# 100000
# 0.08875967386029515
# 0.0
# Total Iterations:  3
#
# 28
# Objective Value Convergence per Iteration
# 100000
# 0.08736536581426435
# 0.0
# Total Iterations:  3
#
# 29
# Objective Value Convergence per Iteration
# 100000
# 0.08570286985570874
# 0.0
# Total Iterations:  3
#
# 30
# Objective Value Convergence per Iteration
# 100000
# 0.060805930838967015
# 0.01961051572118322
# 0.0
# Total Iterations:  4
#
# 31
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 32
# Objective Value Convergence per Iteration
# 100000
# 0.045101559847921635
# 0.019062313414622167
# 0.0
# Total Iterations:  4
#
# 33
# Objective Value Convergence per Iteration
# 100000
# 0.0
# Total Iterations:  2
#
# 34
# Objective Value Convergence per Iteration
# 100000
# 0.24983767151803704
# 0.18178388425184266
# 0.4047984041305881
# 0.5679860267194954
# 0.21236334769423593
# 0.039379324245828684
# 0.023660894937222565
# 0.028761599941674376
# 0.2246797821965174
# 1.1679209587059631
# 1.2439292010382133
# 1.533556744457485
# 2.247031604565848
# 2.4039149007618335
# 0.9022795426189418
# 0.4315498258486059
# 0.020514012697162798
# 0.01673800879399323
# 0.0
# Total Iterations:  20
#
# 35
# Objective Value Convergence per Iteration
# 100000
# 0.017034017271896573
# 0.0
# Total Iterations:  3
#
# 36
# Objective Value Convergence per Iteration
# 100000
# 0.019530584670690132
# 0.07363776748366035
# 0.018044633088607043
# 0.0
# Total Iterations:  5
#
# 37
# Objective Value Convergence per Iteration
# 100000
# 0.18536912587313736
# 0.0
# Total Iterations:  3
#
# 38
# Objective Value Convergence per Iteration
# 100000
# 0.04467469676893643
# 0.01802302087685348
# 0.0
# Total Iterations:  4
#
# 39
# Objective Value Convergence per Iteration
# 100000
# 0.18496812095037285
# 0.0
# Total Iterations:  3
#
# 40
# Objective Value Convergence per Iteration
# 100000
# 0.2062668854180174
# 0.0
# Total Iterations:  3
#
# 41
# Objective Value Convergence per Iteration
# 100000
# 0.5048821490286173
# 0.2586302985828297
# 0.32544360046154
# 0.1484582148912068
# 0.1864310557594422
# 0.2566862035172903
# 0.06107659958081513
# 0.0
# Total Iterations:  9
#
# 42
# Objective Value Convergence per Iteration
# 100000
# 0.4999930672171331
# 0.2561879294177629
# 0.32008680585363436
# 0.13876534206491442
# 0.18051866159754582
# 0.2630144080366108
# 0.06097575207428463
# 0.0
# Total Iterations:  9
#
# 43
# Objective Value Convergence per Iteration
# 100000
# 0.20578599819157262
# 0.0
# Total Iterations:  3
#
# 44
# Objective Value Convergence per Iteration
# 100000
# 0.20565515890126562
# 0.0
# Total Iterations:  3
#
# 45
# Objective Value Convergence per Iteration
# 100000
# 0.02618430070293698
# 0.0
# Total Iterations:  3

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.title('GDP Quarterly Forecast',fontsize='20')
plt.plot(df_gdp_ft_test[1:].index, preds[:])
plt.plot(df_gdp_ft_test[1:].index, data_test_x[1:,0])
y_min, y_max = plt.ylim()
plt.fill_between(df_gdp_ft_test[1:].index, 
                 y_min, y_max,
                 where=sPreds == 1, 
                 color='blue', alpha=0.13)
plt.text(df_gdp_ft_test[1:].index[-1],
         y_min + (y_max - y_min) * 0.05,
         'Blue Shaded Region: Forecasted Recessionary State',
         color='blue', 
         ha='right',
         va='bottom', 
         fontsize=12, 
         fontweight='bold', 
         alpha=0.5)
plt.legend(('Prediction', 'Actual'))
plt.ylabel('% Change in GDP Output')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
print('2-Norm Error: ', np.linalg.norm(preds[:] - data_test_x[1:,0]))
# Out:
# 2-Norm Error:  4.634854074979093
