# %% [markdown]
# Note: ChatGPT was utilized for coding.
#
# “ChatGPT: State labeling and optimization,” ChatGPT: Array copy issue,” "ChatGPT: Overlay plot with shading,” "ChatGPT: K-means++ randomness issue,” "ChatGPT: Markov switching forecasting issues,” “ChatGPT: Real-time forecasting with AR." ChatGPT. [Online] Available:
# https://chatgpt.com/share/67c27bc7-9fc0-8005-bb81-8c4bbb17d290, https://chatgpt.com/share/67f176a4-e370-8005-a9f6-6907f2212a13, https://chatgpt.com/share/67f18721-6500-8005-b89d-4c7e05fb6db7, https://chatgpt.com/share/67da1ae1-0544-8005-a569-413cbf705e6c, https://chatgpt.com/share/67f186e6-be48-8005-829b-0cf38c07c1f6, https://chatgpt.com/share/67f08ee9-9390-8005-877d-0d078b4adeab.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cvxpy as cp
from sklearn.cluster import KMeans
import xgboost as xgb

# %% [markdown]
# # **Step 0: Read FRED GDP Data**

# %%
# Read GDP File
df_gdp = pd.read_csv('rGDP_JS.csv')
df_gdp['observation_date'] = pd.to_datetime(df_gdp.observation_date)
df_gdp.set_index('observation_date', inplace=True)

# %%
# Plot GDP
plt.figure(figsize=(12, 6))
plt.plot(df_gdp)
plt.xlabel('Year')
plt.ylabel('% Growth')
plt.title('US GDP Growth Overtime', fontsize='20')
# Out:
# Text(0.5, 1.0, 'US GDP Growth Overtime')

# %% [markdown]
# # **Step 1: Regime Identification**

# %% [markdown]
# ## **i. Feature Generation** *(Nystrup, et al. 2020)*

# %%
# Select Window Length
w1 = 6
w2 = 14

# %%
df_gdp_ft = df_gdp[max(w1, w2) - 1:]

# %% [markdown]
# *Absolute Change*

# %%
abs_change = []

for i in range(len(df_gdp_ft)):
  absChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 1] - df_gdp.rGDP[i + max(w1, w2) - 2])
  abs_change.append(absChange)

df_gdp_ft["AbsChange"] = abs_change
# Out:
# /tmp/ipykernel_661344/3168161603.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   absChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 1] - df_gdp.rGDP[i + max(w1, w2) - 2])
# /tmp/ipykernel_661344/3168161603.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["AbsChange"] = abs_change

# %% [markdown]
# *Previous Absolute Change*

# %%
prev_abs_change = []

for i in range(len(df_gdp_ft)):
  prevAbsChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 2] - df_gdp.rGDP[i + max(w1, w2) - 3])
  prev_abs_change.append(prevAbsChange)

df_gdp_ft["PrevAbs Change"] = prev_abs_change
# Out:
# /tmp/ipykernel_661344/1066985137.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   prevAbsChange = np.abs(df_gdp.rGDP[i + max(w1, w2) - 2] - df_gdp.rGDP[i + max(w1, w2) - 3])
# /tmp/ipykernel_661344/1066985137.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["PrevAbs Change"] = prev_abs_change

# %% [markdown]
# **Features at w = 14**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)"] = centered_mean
df_gdp_ft["CenteredStd(14)"] = centered_std
# Out:
# /tmp/ipykernel_661344/603088380.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_661344/603088380.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)"] = centered_mean
# /tmp/ipykernel_661344/603088380.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)"] = left_mean
df_gdp_ft["LeftStd(14)"] = left_std
# Out:
# /tmp/ipykernel_661344/2429308197.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_661344/2429308197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)"] = left_mean
# /tmp/ipykernel_661344/2429308197.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)"] = right_mean
df_gdp_ft["RightStd(14)"] = right_std
# Out:
# /tmp/ipykernel_661344/1295607971.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_661344/1295607971.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)"] = right_mean
# /tmp/ipykernel_661344/1295607971.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)"] = right_std

# %% [markdown]
# **Features at w = 6**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)"] = centered_mean
df_gdp_ft["CenteredStd(6)"] = centered_std
# Out:
# /tmp/ipykernel_661344/1041938135.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_661344/1041938135.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)"] = centered_mean
# /tmp/ipykernel_661344/1041938135.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)"] = left_mean
df_gdp_ft["LeftStd(6)"] = left_std
# Out:
# /tmp/ipykernel_661344/726827072.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_661344/726827072.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)"] = left_mean
# /tmp/ipykernel_661344/726827072.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)"] = right_mean
df_gdp_ft["RightStd(6)"] = right_std
# Out:
# /tmp/ipykernel_661344/3669477337.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_661344/3669477337.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)"] = right_mean
# /tmp/ipykernel_661344/3669477337.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)"] = right_std

# %% [markdown]
# **What we have now:** 15-dimensional feature vector for the rGDP return Time Series

# %%
df_gdp_ft
# Out:
#                   rGDP  AbsChange  PrevAbs Change  CenteredMean(14)  \
# observation_date
# 1950-07-01         3.9        0.8             0.8          1.028571
# 1950-10-01         1.9        2.0             0.8          1.185714
# 1951-01-01         1.4        0.5             2.0          1.300000
# 1951-04-01         1.7        0.3             0.5          1.307143
# 1951-07-01         2.1        0.4             0.3          1.350000
# ...                ...        ...             ...               ...
# 2023-04-01         0.6        0.1             0.1          0.564286
# 2023-07-01         1.1        0.5             0.1          0.742857
# 2023-10-01         0.8        0.3             0.5          1.364286
# 2024-01-01         0.4        0.4             0.3          0.835714
# 2024-04-01         0.7        0.3             0.4          0.807143
#
#                   CenteredStd(14)  LeftMean(14)  LeftStd(14)  RightMean(14)  \
# observation_date
# 1950-07-01               1.628070      0.714286     0.813157       1.342857
# 1950-10-01               1.598149      0.557143     1.062150       1.814286
# 1951-01-01               1.551497      0.542857     1.072856       2.057143
# 1951-04-01               1.553091      0.457143     1.006915       2.157143
# 1951-07-01               1.566046      0.128571     0.988092       2.571429
# ...                           ...           ...          ...            ...
# 2023-04-01               3.077710      0.500000     4.309458       0.628571
# 2023-07-01               3.030727      0.957143     4.253018       0.528571
# 2023-10-01               1.861108      2.042857     2.434782       0.685714
# 2024-01-01               0.540644      0.942857     0.722806       0.728571
# 2024-04-01               0.536476      0.885714     0.723935       0.728571
#
#                   RightStd(14)  CenteredMean(6)  CenteredStd(6)  LeftMean(6)  \
# observation_date
# 1950-07-01            2.107712         1.800000        1.928730    -0.033333
# 1950-10-01            1.786000         2.166667        1.688852     1.366667
# 1951-01-01            1.586422         2.233333        1.648905     2.066667
# 1951-04-01            1.537955         2.650000        1.029158     3.633333
# 1951-07-01            0.972059         2.350000        0.871302     2.966667
# ...                        ...              ...             ...          ...
# 2023-04-01            0.604068         0.433333        0.398609     0.166667
# 2023-07-01            0.436592         0.666667        0.298142     0.533333
# 2023-10-01            0.279942         0.783333        0.157233     0.733333
# 2024-01-01            0.197949         0.733333        0.213437     0.700000
# 2024-04-01            0.197949         0.716667        0.211476     0.800000
#
#                   LeftStd(6)  RightMean(6)  RightStd(6)
# observation_date
# 1950-07-01          0.758654      3.633333     0.377124
# 1950-10-01          1.936205      2.966667     0.821922
# 1951-01-01          2.053182      2.400000     1.080123
# 1951-04-01          0.377124      1.666667     0.205480
# 1951-07-01          0.821922      1.733333     0.286744
# ...                      ...           ...          ...
# 2023-04-01          0.410961      0.700000     0.081650
# 2023-07-01          0.309121      0.800000     0.216025
# 2023-10-01          0.047140      0.833333     0.205480
# 2024-01-01          0.081650      0.766667     0.286744
# 2024-04-01          0.216025      0.633333     0.169967
#
# [296 rows x 15 columns]

# %%
# Determine Training and Testing Period
df_gdp_ft_train = df_gdp_ft [:220]
df_gdp_ft_test = df_gdp_ft[220-1:-30]

# %% [markdown]
# ## **ii. Model Fitting** *(Nystrup, et al. 2020)*

# %% [markdown]
# CVXPY Citation: https://drive.google.com/file/d/1VyB1QPfnzWfribfMdIJNdSlcbFsUQuqu/view?usp=sharing
#
# K-Means Citation: https://scikit-learn.org/1.5/modules/generated/sklearn.cluster.KMeans.html

# %%
np_gdp_ft = df_gdp_ft_train.to_numpy()

# %% [markdown]
# **Step 1:** Initialization of Initial State Sequence

# %%
kmeans = KMeans(n_clusters=2, random_state=0, init='k-means++', n_init="auto").fit(np_gdp_ft)
kmeans_labels = kmeans.labels_
s_hat_hold = kmeans_labels

# %% [markdown]
# **Step 2:** Running Jump Estimation Algorithm

# %%
import cvxpy as cp

objectiveValuePrev = 0
objectiveValueCurrent = 0
objectiveValueDiff = 100000

n = 0
T = np_gdp_ft.shape[0]
D = df_gdp_ft.shape[1]
lamda = 1 # IMPROVEMENT: To change to "optimal" jump penalty
print("Objective Value Convergence per Iteration")

while objectiveValueDiff > 10e-6:

  # ----------------- MODEL FITTING COMPONENT ------------------------
  #      (input: a state sequence s_hat_hold and series np_gdp_ft)

  # Declare Variables
  theta0 = cp.Variable(D)
  theta1 = cp.Variable(D)

  # Objective Function
  loss = 0
  for i in range(T):
    if (s_hat_hold[i] == 0):
      loss = cp.sum_squares(np_gdp_ft[i] - theta0) + loss
    if (s_hat_hold[i] == 1):
      loss = cp.sum_squares(np_gdp_ft[i] - theta1) + loss
  objective = cp.Minimize((1/2)*loss)

  # Solve Problem
  problem = cp.Problem(objective)
  problem.solve()

  # ----------------- STATE-SEQUENCE FITTING ------------------------
  #      (input: parameter vector theta_0 and theta_1)

  # Populate Loss Matrix L
  K = 2 # Number of States
  L = np.zeros((T,K))
  for i in range(T):
    L[i][0] = (1/2) * np.linalg.norm(np_gdp_ft[i] - theta0.value)**2
    L[i][1] = (1/2) * np.linalg.norm(np_gdp_ft[i] - theta1.value)**2

  # Begin Dynamic Programming
  V = np.zeros((T,K)) # starting from t=1, not t=0
  V[0][0] = L[0][0] # Initialization
  V[0][1] = L[0][1] # Initialization

  # Populate V Matrix for k = 0,1
  for i in range(T - 1):
    V[i + 1][0] = L[i + 1][0] + min(V[i][0], V[i][1] + lamda)
    V[i + 1][1] = L[i + 1][1] + min(V[i][0] + lamda, V[i][1])

  # Compute Optimal Value and Optimal Final State
  objectiveValue = min(V[T-1][0], V[T-1][1])
  s_hat = np.zeros(T)
  s_hat[T-1] = np.argmin([V[T-1][0], V[T-1][1]])

  # Retrace State Sequence s_hat from Optimal Value
  for i in range(T-1):
      if (s_hat[T-1-i] == 0):
          s_hat[T-2-i] = np.argmin([V[T-2-i][0],V[T-2-i][1] + lamda])
      if (s_hat[T-1-i] == 1):
          s_hat[T-2-i] = np.argmin([V[T-2-i][0] + lamda,V[T-2-i][1]])

  # Calculating Convergence Improvement per Iteration
  if (n == 0):
    objectiveValuePrev = objectiveValue
  if (n > 0):
    objectiveValueCurrent = objectiveValue
    objectiveValueDiff = np.abs(objectiveValuePrev - objectiveValueCurrent)
    objectiveValuePrev = objectiveValueCurrent

  n = n + 1
  print(objectiveValueDiff)

  s_hat_hold = s_hat

# ----------------- DEFINE RECESSIONARY REGIME ------------------------

# Define s_t = 1 as the recessionary regime
if (theta1.value[0] > theta0.value[0]):
    for i in range(len(s_hat_hold)):
        if (s_hat_hold[i] == 0):
            s_hat_hold[i] = 1
        else:
            s_hat_hold[i] = 0
    theta0_value = theta1.value.copy()
    theta1_value = theta0.value.copy()

else:
    theta0_value = theta0.value.copy()
    theta1_value = theta1.value.copy()

print()
print('Total Iterations: ', n)
# Out:
# Objective Value Convergence per Iteration
# 100000
# 1.4090427824244216
# 0.6756661968607887
# 0.604471376820527
# 0.598061089822636
# 0.0
#
# Total Iterations:  6

# %% [markdown]
# # **Step 2: GDP Forecast**

# %% [markdown]
# **What we have now:** **1)** Optimal State Sequence up to T and **2)** Optimal Parameters for State 0 and 1

# %%
Df_s_hat = pd.DataFrame(s_hat_hold)
plt.figure(figsize=(12, 6))
plt.plot(df_gdp_ft_train.index, Df_s_hat)
plt.xlabel('Year')
plt.ylabel('Recession')
plt.title('Jump Model Optimal State Sequence', fontsize='20')
# Out:
# Text(0.5, 1.0, 'Jump Model Optimal State Sequence')

# %%
print('State 0 Optimal Parameter: ')
print(theta0.value)
print()
print('State 1 Optimal Parameter: ')
print(theta1.value)
# Out:
# State 0 Optimal Parameter:
# [0.2296875  1.2015625  1.203125   0.65078125 1.03001795 0.95915179
#  0.88795204 0.34241071 0.95166059 0.27395833 0.93757677 0.39114583
#  0.72814992 0.15677083 0.76941756]
#
# State 1 Optimal Parameter:
# [1.12435897 0.68910256 0.68974359 0.96021062 0.80712286 0.8253663
#  0.75007304 1.09505495 0.68769007 1.12532051 0.64601839 1.0792735
#  0.49847809 1.17136752 0.4538409 ]

# %% [markdown]
# ---

# %% [markdown]
# **Method 1:** For each out of sample data, calculate loss function to classify which state it belongs to, and then use XGBoost to predict {y_t, y_t+1}

# %%
# Pairwise Values to Train: (z_t, z_t+1) s.t z = (x_t , s_t)
data_train_y_copy = np.zeros((len(s_hat_hold),2))
for i in range(len(s_hat_hold)):
  data_train_y_copy[i][0] = np_gdp_ft[:,0][i].copy()
  data_train_y_copy[i][1] = s_hat_hold[i].copy()

data_train_y = data_train_y_copy[:len(data_train_y_copy)-1].copy()
data_train_yeff = data_train_y_copy[1:].copy()

# Train with XGB
dtrain = xgb.DMatrix(data_train_y, data_train_yeff)
params = {}
bst = xgb.train(params, dtrain)

# %%
testingSet = df_gdp_ft_test.to_numpy()

# %%
prediction = np.zeros((len(testingSet)-1,2))
prevState = np.zeros(len(testingSet))
prevState[0] = s_hat_hold[T-1]

for i in range(len(testingSet)-1):

  # ------------------ PREDICT NEXT PERIOD {y_t+1} -------------------------

  # Format Out of Sample Data to make it {y_t} form
  y_t = np.array([[testingSet[i][0],prevState[i]]])

  # Out of Sample Testing
  dtest = xgb.DMatrix(y_t)
  ypred = bst.predict(dtest)
  prediction[i] = ypred

  # -------------------- CLASSIFY NEXT REGIME -------------------------------

  loss_s0 = 0
  loss_s1 = 0
  if (int(prevState[i]) == 0):
    loss_s0 = (1/2) * (np.linalg.norm(testingSet[i+1] - theta0_value))**2
    loss_s1 = (1/2) * (np.linalg.norm(testingSet[i+1] - theta1_value))**2 + lamda
  if (int(prevState[i]) == 1):
    loss_s0 = (1/2) * (np.linalg.norm(testingSet[i+1] - theta0_value))**2 + lamda
    loss_s1 = (1/2) * (np.linalg.norm(testingSet[i+1] - theta1_value))**2

  prevState[i+1] = np.argmin((loss_s0,loss_s1))

# %%
plt.plot(df_gdp_ft_test[1:].index, prediction[:,0])
plt.plot(df_gdp_ft_test[1:].index, testingSet[1:,0])
plt.legend(('Prediction', 'Actual'))
plt.title('GDP Quarterly Forecast')
plt.xlabel('Years')
plt.ylabel('GDP Quarterly Growth')
# Out:
# Text(0, 0.5, 'GDP Quarterly Growth')

# %%
print('2-Norm Error: ', np.linalg.norm(prediction[:,0] - testingSet[1:,0]))
# Out:
# 2-Norm Error:  5.325502392162437

# %%
plt.plot(df_gdp_ft_test[1:].index, prediction[:,1])
plt.title('Regime Forecast of Out of Sample Data')
plt.ylabel('Recession')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
plt.plot(df_gdp_ft_test[1:].index, prevState[:-1])
plt.title('Regime Classification of Out of Sample Data')
plt.ylabel('Recession')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')
