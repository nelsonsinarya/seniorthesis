# %% [markdown]
# Note: ChatGPT was utilized for coding.
#
# “ChatGPT: State labeling and optimization,” ChatGPT: Array copy issue,” "ChatGPT: Overlay plot with shading,” "K-means++ randomness issue,” "Markov switching forecasting issues,” “ChatGPT: Real-time forecasting with AR." ChatGPT. [Online] Available:
# https://chatgpt.com/share/67c27bc7-9fc0-8005-bb81-8c4bbb17d290, https://chatgpt.com/share/67f176a4-e370-8005-a9f6-6907f2212a13, https://chatgpt.com/share/67f18721-6500-8005-b89d-4c7e05fb6db7, https://chatgpt.com/share/67da1ae1-0544-8005-a569-413cbf705e6c, https://chatgpt.com/share/67f186e6-be48-8005-829b-0cf38c07c1f6, https://chatgpt.com/share/67f08ee9-9390-8005-877d-0d078b4adeab.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cvxpy as cp
from sklearn.cluster import KMeans
import xgboost as xgb
from xgboost import XGBClassifier

# %% [markdown]
# # **Read FRED GDP Data**

# %%
# Read GDP File
df_gdp = pd.read_csv('Updated GlobalMultiData copy 1.csv')
df_gdp['observation_date'] = pd.to_datetime(df_gdp.observation_date)
df_gdp.set_index('observation_date', inplace=True)

# %%
# Plot GDP
plt.figure(figsize=(12, 6))
plt.plot(df_gdp['rGDP'])
plt.xlabel('Year')
plt.ylabel('% Growth')
plt.title('US GDP Growth Overtime', fontsize='20')
# Out:
# Text(0.5, 1.0, 'US GDP Growth Overtime')

# %% [markdown]
# # **Step 1: Regime Identification**

# %% [markdown]
# ## **i. Feature Generation** *(Nystrup, et al. 2020)*

# %%
# Select Window Length
w1 = 6
w2 = 14

# %%
df_gdp_ft = df_gdp[max(w1, w2) - 1:]

# %% [markdown]
# **Features at w = 14**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)"] = centered_mean
df_gdp_ft["CenteredStd(14)"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_BBKQLEIX"] = centered_mean
df_gdp_ft["CenteredStd(14)_BBKQLEIX"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_NFCIPCH"] = centered_mean
df_gdp_ft["CenteredStd(14)_NFCIPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_NFCINONFINLEVERAGEPC1"] = centered_mean
df_gdp_ft["CenteredStd(14)_NFCINONFINLEVERAGEPC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_T10Y2Y_PCH"] = centered_mean
df_gdp_ft["CenteredStd(14)_T10Y2Y_PCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_T10Y2Y_PC1"] = centered_mean
df_gdp_ft["CenteredStd(14)_T10Y2Y_PC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_MICHPCH"] = centered_mean
df_gdp_ft["CenteredStd(14)_MICHPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_UNRATEPCH"] = centered_mean
df_gdp_ft["CenteredStd(14)_UNRATEPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_WTISPLC_PC1"] = centered_mean
df_gdp_ft["CenteredStd(14)_WTISPLC_PC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w2):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w2 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(14)_T10YFF_CH1"] = centered_mean
df_gdp_ft["CenteredStd(14)_T10YFF_CH1"] = centered_std
# Out:
# /tmp/ipykernel_1111387/3061342102.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_BBKQLEIX"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_BBKQLEIX"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_NFCIPCH"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_NFCIPCH"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_NFCINONFINLEVERAGEPC1"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_NFCINONFINLEVERAGEPC1"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_T10Y2Y_PCH"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_T10Y2Y_PCH"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_T10Y2Y_PC1"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_T10Y2Y_PC1"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_MICHPCH"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_MICHPCH"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_UNRATEPCH"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_UNRATEPCH"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_WTISPLC_PC1"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_WTISPLC_PC1"] = centered_std
# /tmp/ipykernel_1111387/3061342102.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/3061342102.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(14)_T10YFF_CH1"] = centered_mean
# /tmp/ipykernel_1111387/3061342102.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(14)_T10YFF_CH1"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)"] = left_mean
df_gdp_ft["LeftStd(14)"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_BBKQLEIX"] = left_mean
df_gdp_ft["LeftStd(14)_BBKQLEIX"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_NFCIPCH"] = left_mean
df_gdp_ft["LeftStd(14)_NFCIPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_NFCINONFINLEVERAGEPC1"] = left_mean
df_gdp_ft["LeftStd(14)_NFCINONFINLEVERAGEPC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_T10Y2Y_PCH"] = left_mean
df_gdp_ft["LeftStd(14)_T10Y2Y_PCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_T10Y2Y_PC1"] = left_mean
df_gdp_ft["LeftStd(14)_T10Y2Y_PC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_MICHPCH"] = left_mean
df_gdp_ft["LeftStd(14)_MICHPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_UNRATEPCH"] = left_mean
df_gdp_ft["LeftStd(14)_UNRATEPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_WTISPLC_PC1"] = left_mean
df_gdp_ft["LeftStd(14)_WTISPLC_PC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 14 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 7])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w2 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(14)_T10YFF_CH1"] = left_mean
df_gdp_ft["LeftStd(14)_T10YFF_CH1"] = left_std
# Out:
# /tmp/ipykernel_1111387/816511192.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)"] = left_std
# /tmp/ipykernel_1111387/816511192.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_BBKQLEIX"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_BBKQLEIX"] = left_std
# /tmp/ipykernel_1111387/816511192.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_NFCIPCH"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_NFCIPCH"] = left_std
# /tmp/ipykernel_1111387/816511192.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_NFCINONFINLEVERAGEPC1"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_NFCINONFINLEVERAGEPC1"] = left_std
# /tmp/ipykernel_1111387/816511192.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_T10Y2Y_PCH"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_T10Y2Y_PCH"] = left_std
# /tmp/ipykernel_1111387/816511192.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_T10Y2Y_PC1"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_T10Y2Y_PC1"] = left_std
# /tmp/ipykernel_1111387/816511192.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_MICHPCH"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_MICHPCH"] = left_std
# /tmp/ipykernel_1111387/816511192.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_UNRATEPCH"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_UNRATEPCH"] = left_std
# /tmp/ipykernel_1111387/816511192.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_WTISPLC_PC1"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_WTISPLC_PC1"] = left_std
# /tmp/ipykernel_1111387/816511192.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w2 + j])
# /tmp/ipykernel_1111387/816511192.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(14)_T10YFF_CH1"] = left_mean
# /tmp/ipykernel_1111387/816511192.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(14)_T10YFF_CH1"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)"] = right_mean
df_gdp_ft["RightStd(14)"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_BBKQLEIX"] = right_mean
df_gdp_ft["RightStd(14)_BBKQLEIX"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_NFCIPCH"] = right_mean
df_gdp_ft["RightStd(14)_NFCIPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_NFCINONFINLEVERAGEPC1"] = right_mean
df_gdp_ft["RightStd(14)_NFCINONFINLEVERAGEPC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_T10Y2Y_PCH"] = right_mean
df_gdp_ft["RightStd(14)_T10Y2Y_PCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_T10Y2Y_PC1"] = right_mean
df_gdp_ft["RightStd(14)_T10Y2Y_PC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_MICHPCH"] = right_mean
df_gdp_ft["RightStd(14)_MICHPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_UNRATEPCH"] = right_mean
df_gdp_ft["RightStd(14)_UNRATEPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_WTISPLC_PC1"] = right_mean
df_gdp_ft["RightStd(14)_WTISPLC_PC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w2/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 7 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - int(w2/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(14)_T10YFF_CH1"] = right_mean
df_gdp_ft["RightStd(14)_T10YFF_CH1"] = right_std
# Out:
# /tmp/ipykernel_1111387/162213587.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)"] = right_std
# /tmp/ipykernel_1111387/162213587.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_BBKQLEIX"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_BBKQLEIX"] = right_std
# /tmp/ipykernel_1111387/162213587.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_NFCIPCH"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_NFCIPCH"] = right_std
# /tmp/ipykernel_1111387/162213587.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_NFCINONFINLEVERAGEPC1"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_NFCINONFINLEVERAGEPC1"] = right_std
# /tmp/ipykernel_1111387/162213587.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_T10Y2Y_PCH"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_T10Y2Y_PCH"] = right_std
# /tmp/ipykernel_1111387/162213587.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_T10Y2Y_PC1"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_T10Y2Y_PC1"] = right_std
# /tmp/ipykernel_1111387/162213587.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_MICHPCH"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_MICHPCH"] = right_std
# /tmp/ipykernel_1111387/162213587.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_UNRATEPCH"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_UNRATEPCH"] = right_std
# /tmp/ipykernel_1111387/162213587.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_WTISPLC_PC1"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_WTISPLC_PC1"] = right_std
# /tmp/ipykernel_1111387/162213587.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - int(w2/2) + j])
# /tmp/ipykernel_1111387/162213587.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(14)_T10YFF_CH1"] = right_mean
# /tmp/ipykernel_1111387/162213587.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(14)_T10YFF_CH1"] = right_std

# %% [markdown]
# **Features at w = 6**

# %% [markdown]
# *Center Component*

# %%
centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)"] = centered_mean
df_gdp_ft["CenteredStd(6)"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_BBKQLEIX"] = centered_mean
df_gdp_ft["CenteredStd(6)_BBKQLEIX"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_NFCIPCH"] = centered_mean
df_gdp_ft["CenteredStd(6)_NFCIPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_NFCINONFINLEVERAGEPC1"] = centered_mean
df_gdp_ft["CenteredStd(6)_NFCINONFINLEVERAGEPC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_T10Y2Y_PCH"] = centered_mean
df_gdp_ft["CenteredStd(6)_T10Y2Y_PCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_T10Y2Y_PC1"] = centered_mean
df_gdp_ft["CenteredStd(6)_T10Y2Y_PC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_MICHPCH"] = centered_mean
df_gdp_ft["CenteredStd(6)_MICHPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_UNRATEPCH"] = centered_mean
df_gdp_ft["CenteredStd(6)_UNRATEPCH"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_WTISPLC_PC1"] = centered_mean
df_gdp_ft["CenteredStd(6)_WTISPLC_PC1"] = centered_std

centered_mean = []
centered_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(w1):
    # Mean and Std from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w1 + j])
  centeredMean = np.average(hold)
  centeredStd = np.std(hold)
  centered_mean.append(centeredMean)
  centered_std.append(centeredStd)

df_gdp_ft["CenteredMean(6)_T10YFF_CH1"] = centered_mean
df_gdp_ft["CenteredStd(6)_T10YFF_CH1"] = centered_std
# Out:
# /tmp/ipykernel_1111387/1343661107.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_BBKQLEIX"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_BBKQLEIX"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_NFCIPCH"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_NFCIPCH"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_NFCINONFINLEVERAGEPC1"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_NFCINONFINLEVERAGEPC1"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_T10Y2Y_PCH"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_T10Y2Y_PCH"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_T10Y2Y_PC1"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_T10Y2Y_PC1"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_MICHPCH"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_MICHPCH"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_UNRATEPCH"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_UNRATEPCH"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_WTISPLC_PC1"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_WTISPLC_PC1"] = centered_std
# /tmp/ipykernel_1111387/1343661107.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/1343661107.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredMean(6)_T10YFF_CH1"] = centered_mean
# /tmp/ipykernel_1111387/1343661107.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["CenteredStd(6)_T10YFF_CH1"] = centered_std

# %% [markdown]
# *Left Component*

# %%
left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)"] = left_mean
df_gdp_ft["LeftStd(6)"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_BBKQLEIX"] = left_mean
df_gdp_ft["LeftStd(6)_BBKQLEIX"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_NFCIPCH"] = left_mean
df_gdp_ft["LeftStd(6)_NFCIPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_NFCINONFINLEVERAGEPC1"] = left_mean
df_gdp_ft["LeftStd(6)_NFCINONFINLEVERAGEPC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_T10Y2Y_PCH"] = left_mean
df_gdp_ft["LeftStd(6)_T10Y2Y_PCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_T10Y2Y_PC1"] = left_mean
df_gdp_ft["LeftStd(6)_T10Y2Y_PC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_MICHPCH"] = left_mean
df_gdp_ft["LeftStd(6)_MICHPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_UNRATEPCH"] = left_mean
df_gdp_ft["LeftStd(6)_UNRATEPCH"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_WTISPLC_PC1"] = left_mean
df_gdp_ft["LeftStd(6)_WTISPLC_PC1"] = left_std

left_mean = []
left_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 6 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1 - 3])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w1 + j])
  leftMean = np.average(hold)
  leftStd = np.std(hold)
  left_mean.append(leftMean)
  left_std.append(leftStd)

df_gdp_ft["LeftMean(6)_T10YFF_CH1"] = left_mean
df_gdp_ft["LeftStd(6)_T10YFF_CH1"] = left_std
# Out:
# /tmp/ipykernel_1111387/3838373659.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_BBKQLEIX"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_BBKQLEIX"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_NFCIPCH"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_NFCIPCH"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_NFCINONFINLEVERAGEPC1"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_NFCINONFINLEVERAGEPC1"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_T10Y2Y_PCH"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_T10Y2Y_PCH"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_T10Y2Y_PC1"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_T10Y2Y_PC1"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_MICHPCH"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_MICHPCH"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_UNRATEPCH"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_UNRATEPCH"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_WTISPLC_PC1"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_WTISPLC_PC1"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - w1 + j])
# /tmp/ipykernel_1111387/3838373659.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftMean(6)_T10YFF_CH1"] = left_mean
# /tmp/ipykernel_1111387/3838373659.py:159: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["LeftStd(6)_T10YFF_CH1"] = left_std
# /tmp/ipykernel_1111387/3838373659.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["LeftStd(6)_T10YFF_CH1"] = left_std

# %% [markdown]
# *Right Component*

# %%
right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)"] = right_mean
df_gdp_ft["RightStd(6)"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_BBKQLEIX"] = right_mean
df_gdp_ft["RightStd(6)_BBKQLEIX"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_NFCIPCH"] = right_mean
df_gdp_ft["RightStd(6)_NFCIPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_NFCINONFINLEVERAGEPC1"] = right_mean
df_gdp_ft["RightStd(6)_NFCINONFINLEVERAGEPC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_T10Y2Y_PCH"] = right_mean
df_gdp_ft["RightStd(6)_T10Y2Y_PCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_T10Y2Y_PC1"] = right_mean
df_gdp_ft["RightStd(6)_T10Y2Y_PC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_MICHPCH"] = right_mean
df_gdp_ft["RightStd(6)_MICHPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_UNRATEPCH"] = right_mean
df_gdp_ft["RightStd(6)_UNRATEPCH"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_WTISPLC_PC1"] = right_mean
df_gdp_ft["RightStd(6)_WTISPLC_PC1"] = right_std

right_mean = []
right_std = []

for i in range(len(df_gdp_ft)):
  hold = []
  for j in range(int(w1/2)):
    # Mean from np.abs(df_gdp.rGDP[i + max(w1, w2) - 1 - 3 + 1] to df_gdp.rGDP[i + max(w1, w2) - 1])
    hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - int(w1/2) + j])
  rightMean = np.average(hold)
  rightStd = np.std(hold)
  right_mean.append(rightMean)
  right_std.append(rightStd)

df_gdp_ft["RightMean(6)_T10YFF_CH1"] = right_mean
df_gdp_ft["RightStd(6)_T10YFF_CH1"] = right_std
# Out:
# /tmp/ipykernel_1111387/1594713726.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.rGDP[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:15: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:24: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.BBKQLEIX[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:30: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_BBKQLEIX"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_BBKQLEIX"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_BBKQLEIX"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_BBKQLEIX"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCI_PCH[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:46: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_NFCIPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_NFCIPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_NFCIPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_NFCIPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:56: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.NFCINONFINLEVERAGE_PC1[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:62: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_NFCINONFINLEVERAGEPC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_NFCINONFINLEVERAGEPC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:63: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_NFCINONFINLEVERAGEPC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_NFCINONFINLEVERAGEPC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:72: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PCH[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:78: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_T10Y2Y_PCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_T10Y2Y_PCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:79: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_T10Y2Y_PCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_T10Y2Y_PCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:88: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10Y2Y_PC1[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:94: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_T10Y2Y_PC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_T10Y2Y_PC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_T10Y2Y_PC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_T10Y2Y_PC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:104: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.MICH_PCH[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:110: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_MICHPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:110: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_MICHPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:111: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_MICHPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:111: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_MICHPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:120: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.UNRATE_PCH[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:126: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_UNRATEPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:126: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_UNRATEPCH"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:127: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_UNRATEPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_UNRATEPCH"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:136: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.WTISPLC_PC1[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:142: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_WTISPLC_PC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:142: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_WTISPLC_PC1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:143: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_WTISPLC_PC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_WTISPLC_PC1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:152: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   hold.append(df_gdp.T10YFF_CH1[i + max(w1, w2) - int(w1/2) + j])
# /tmp/ipykernel_1111387/1594713726.py:158: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightMean(6)_T10YFF_CH1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:158: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightMean(6)_T10YFF_CH1"] = right_mean
# /tmp/ipykernel_1111387/1594713726.py:159: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_gdp_ft["RightStd(6)_T10YFF_CH1"] = right_std
# /tmp/ipykernel_1111387/1594713726.py:159: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_gdp_ft["RightStd(6)_T10YFF_CH1"] = right_std

# %% [markdown]
# **What we have now:** 15-dimensional feature vector for the rGDP return Time Series

# %% [markdown]
# **Note:** Use before 2000 as training, and after 2000 as testing dataset

# %%
# Determine Training and Testing Period
df_gdp_ft_train = df_gdp_ft [:84]
df_gdp_ft_test = df_gdp_ft[84-1:-30]

# %% [markdown]
# # **Step 2: Regime Fitting Forecast**

# %% [markdown]
# CVXPY Citation: https://drive.google.com/file/d/1VyB1QPfnzWfribfMdIJNdSlcbFsUQuqu/view?usp=sharing
#
# K-Means Citation: https://scikit-learn.org/1.5/modules/generated/sklearn.cluster.KMeans.html

# %% [markdown]
# Utilizing K-Means++ *(Nystrup, et al. 2020)*

# %% [markdown]
# Statistical Jump Model Fitting

# %%
def JM (np_gdp_ft, lamda):

  # ---------------- K-Means Initialization ------------------

  kmeans = KMeans(n_clusters=2, random_state=0, init='k-means++', n_init="auto").fit(np_gdp_ft)
  kmeans_labels = kmeans.labels_
  s_hat_hold = kmeans_labels

  # ------------------------------------------------------------

  objectiveValuePrev = 0
  objectiveValueCurrent = 0
  objectiveValueDiff = 100000

  n = 0
  T = np_gdp_ft.shape[0]
  D = df_gdp_ft.shape[1]
  print("Objective Value Convergence per Iteration (lamda = ", lamda, ")")

  while objectiveValueDiff > 10e-6:

    # ----------------- MODEL FITTING COMPONENT ------------------------
    #      (input: a state sequence s_hat_hold and series np_gdp_ft)

    # Declare Variables
    theta0 = cp.Variable(D)
    theta1 = cp.Variable(D)

    # Objective Function
    loss = 0
    for i in range(T):
      if (s_hat_hold[i] == 0):
        loss = (1/D) * cp.sum_squares(np_gdp_ft[i] - theta0) + loss
      if (s_hat_hold[i] == 1):
        loss = (1/D) * cp.sum_squares(np_gdp_ft[i] - theta1) + loss
    objective = cp.Minimize(loss)

    # Solve Problem
    problem = cp.Problem(objective)
    problem.solve()

    # ----------------- STATE-SEQUENCE FITTING ------------------------
    #      (input: parameter vector theta_0 and theta_1)

    # Populate Loss Matrix L
    K = 2 # Number of States
    L = np.zeros((T,K))
    for i in range(T):
        L[i][0] = (1/D) * np.linalg.norm(np_gdp_ft[i] - theta0.value)**2
        L[i][1] = (1/D) * np.linalg.norm(np_gdp_ft[i] - theta1.value)**2

    # Begin Dynamic Programming
    V = np.zeros((T,K)) # starting from t=1, not t=0
    V[0][0] = L[0][0] # Initialization
    V[0][1] = L[0][1] # Initialization

    # Populate V Matrix for k = 0,1
    for i in range(T - 1):
      V[i + 1][0] = L[i + 1][0] + min(V[i][0], V[i][1] + lamda)
      V[i + 1][1] = L[i + 1][1] + min(V[i][0] + lamda, V[i][1])

    # Compute Optimal Value and Optimal Final State
    objectiveValue = min(V[T-1][0], V[T-1][1])
    s_hat = np.zeros(T)
    s_hat[T-1] = np.argmin([V[T-1][0], V[T-1][1]])

    # Retrace State Sequence s_hat from Optimal Value
    for i in range(T-1):
        if (s_hat[T-1-i] == 0):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0],V[T-2-i][1] + lamda])
        if (s_hat[T-1-i] == 1):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0] + lamda,V[T-2-i][1]])

    # Calculating Convergence Improvement per Iteration
    if (n == 0):
      objectiveValuePrev = objectiveValue
    if (n > 0):
      objectiveValueCurrent = objectiveValue
      objectiveValueDiff = np.abs(objectiveValuePrev - objectiveValueCurrent)
      objectiveValuePrev = objectiveValueCurrent

    n = n + 1
    print(objectiveValueDiff)

    s_hat_hold = s_hat

  # Define s_t = 1 as the recessionary regime
  if (theta1.value[0] > theta0.value[0]):
      for i in range(len(s_hat_hold)):
          if (s_hat_hold[i] == 0):
              s_hat_hold[i] = 1
          else:
              s_hat_hold[i] = 0
      theta0_value = theta1.value.copy()
      theta1_value = theta0.value.copy()
    
  else:
      theta0_value = theta0.value.copy()
      theta1_value = theta1.value.copy()

  print('Total Iterations: ', n)
  return theta0_value, theta1_value, s_hat_hold, V

# %% [markdown]
# Same as above, but with no print statements

# %%
def JMNoPrint (np_gdp_ft, lamda):

  # ---------------- K-Means Initialization ------------------

  kmeans = KMeans(n_clusters=2, random_state=0, init='k-means++', n_init="auto").fit(np_gdp_ft)
  kmeans_labels = kmeans.labels_
  s_hat_hold = kmeans_labels

  # ------------------------------------------------------------

  objectiveValuePrev = 0
  objectiveValueCurrent = 0
  objectiveValueDiff = 100000

  n = 0
  T = np_gdp_ft.shape[0]
  D = df_gdp_ft.shape[1]


  while objectiveValueDiff > 10e-6:

    # ----------------- MODEL FITTING COMPONENT ------------------------
    #      (input: a state sequence s_hat_hold and series np_gdp_ft)

    # Declare Variables
    theta0 = cp.Variable(D)
    theta1 = cp.Variable(D)

    # Objective Function
    loss = 0
    for i in range(T):
      if (s_hat_hold[i] == 0):
        loss = (1/D) * cp.sum_squares(np_gdp_ft[i] - theta0) + loss
      if (s_hat_hold[i] == 1):
        loss = (1/D) * cp.sum_squares(np_gdp_ft[i] - theta1) + loss
    objective = cp.Minimize(loss)

    # Solve Problem
    problem = cp.Problem(objective)
    problem.solve()

    # ----------------- STATE-SEQUENCE FITTING ------------------------
    #      (input: parameter vector theta_0 and theta_1)

    # Populate Loss Matrix L
    K = 2 # Number of States
    L = np.zeros((T,K))
    for i in range(T):
        L[i][0] = (1/D) * np.linalg.norm(np_gdp_ft[i] - theta0.value)**2
        L[i][1] = (1/D) * np.linalg.norm(np_gdp_ft[i] - theta1.value)**2

    # Begin Dynamic Programming
    V = np.zeros((T,K)) # starting from t=1, not t=0
    V[0][0] = L[0][0] # Initialization
    V[0][1] = L[0][1] # Initialization

    # Populate V Matrix for k = 0,1
    for i in range(T - 1):
      V[i + 1][0] = L[i + 1][0] + min(V[i][0], V[i][1] + lamda)
      V[i + 1][1] = L[i + 1][1] + min(V[i][0] + lamda, V[i][1])

    # Compute Optimal Value and Optimal Final State
    objectiveValue = min(V[T-1][0], V[T-1][1])
    s_hat = np.zeros(T)
    s_hat[T-1] = np.argmin([V[T-1][0], V[T-1][1]])

    # Retrace State Sequence s_hat from Optimal Value
    for i in range(T-1):
        if (s_hat[T-1-i] == 0):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0],V[T-2-i][1] + lamda])
        if (s_hat[T-1-i] == 1):
            s_hat[T-2-i] = np.argmin([V[T-2-i][0] + lamda,V[T-2-i][1]])

    # Calculating Convergence Improvement per Iteration
    if (n == 0):
      objectiveValuePrev = objectiveValue
    if (n > 0):
      objectiveValueCurrent = objectiveValue
      objectiveValueDiff = np.abs(objectiveValuePrev - objectiveValueCurrent)
      objectiveValuePrev = objectiveValueCurrent

    n = n + 1
    

    s_hat_hold = s_hat

  # Define s_t = 1 as the recessionary regime
  if (theta1.value[0] > theta0.value[0]):
      for i in range(len(s_hat_hold)):
          if (s_hat_hold[i] == 0):
              s_hat_hold[i] = 1
          else:
              s_hat_hold[i] = 0
      theta0_value = theta1.value.copy()
      theta1_value = theta0.value.copy()
    
  else:
      theta0_value = theta0.value.copy()
      theta1_value = theta1.value.copy()


  return theta0_value, theta1_value, s_hat_hold, V

# %% [markdown]
# Forecasting

# %%
# -------------------- PARAMETER CONTROLS ------------------------
n = 1 # Number of Quarters until Refit and Re-train
m = 100000 # Number of Quarters until Hyperparameter is Tuned
hyperpar_testperiod = 4 # Number of Quarters to Test and Fine Tune Penalty Term
lamda_set = np.logspace(-20,2,5,base=np.sqrt(2))

# %%
# ------------------ DATA AND VARIABLE PREP ----------------------

# Prepare Dataset to Fit Model
np_gdp_ft = df_gdp_ft_train.to_numpy()
T = np_gdp_ft.shape[0]
D = df_gdp_ft.shape[1]

# Prepare Dataset to Retrain JM
np_gdp_ft_retrain = df_gdp_ft_train.to_numpy()

# Prepare Dataset for Out-of-Sample Testing
data_test_x = df_gdp_ft_test.to_numpy() ## State Prediction
preds = np.zeros(len(data_test_x)-1) ## x_t(1) Prediction

# Store State Predictions
sPreds = np.zeros(len(data_test_x)-1)

# First Run of K-Means
kmeans = KMeans(n_clusters=2, random_state=0, init='k-means++', n_init="auto").fit(np_gdp_ft)
kmeans_labels = kmeans.labels_
s_hat_hold = kmeans_labels

# %%
# ------------------- STANDARDIZATION ----------------------
def Standardize (np_gdp_ft):

    np_gdp_ft_standardized = np_gdp_ft.copy()
    
    for i in range(np_gdp_ft.shape[1]):
        np_gdp_ft_standardized[:,i] = (np_gdp_ft[:,i] - np.average(np_gdp_ft[:,i])) / np.std(np_gdp_ft[:,i])
    
    return np_gdp_ft_standardized

# %%
def ReverseStandardize (np_gdp_ft, theta_std):
    mean = np.average(np_gdp_ft[:,0])
    stdev = np.std(np_gdp_ft[:,0])
    theta = (theta_std * stdev) + mean
    return theta
    # return theta_std

# %%
# ------------------- START ITERATIONS ----------------------

count = 0

for i in range(len(data_test_x)-1):

  print(count)
  count = count + 1

  # ----- OPTIMIZING FOR PENALTY TERM (Yizhan Shu, et al.) ------

  if (i%m == 0):
    print("Hyperparamater Tuning In Progress..")
    norm_error = np.zeros(len(lamda_set))
    preds_hyper = np.zeros((len(lamda_set),hyperpar_testperiod)) # Store GDP Hyperparameter Predictions
    sPreds_hyper = np.zeros(hyperpar_testperiod) # Store Hyperparameter Predictions

    for k in range(len(lamda_set)):

      print("Running trial on lamda = ",lamda_set[k])

      for j in range(hyperpar_testperiod):
        np_gdp_ft_std_hyper = Standardize(np_gdp_ft[:-hyperpar_testperiod+j])
        theta0, theta1, s_new, V = JMNoPrint(np_gdp_ft_std_hyper, lamda_set[k])

        # Preparing Dataset to Train (Retrain every period; np_gdp_ft and s_new updates)
        data_train_x = np_gdp_ft_std_hyper[:-1]
        data_train_s_t1 = s_new[1:]

        # Train with XGBClassifier
        bst = XGBClassifier()
        bst.fit(data_train_x, data_train_s_t1)

        # Forecasting and Quantifying Norm Error
        sPred_hyper = bst.predict([np_gdp_ft_std_hyper[-1]])
        sPreds_hyper[j] = sPred_hyper[0]

        if (sPred_hyper[0] == 0):
          RevStdTheta0_hyper = ReverseStandardize(np_gdp_ft[:-hyperpar_testperiod+j], theta0[0])
          preds_hyper[k][j] = RevStdTheta0_hyper

        if (sPred_hyper[0] == 1):
          RevStdTheta1_hyper = ReverseStandardize(np_gdp_ft[:-hyperpar_testperiod+j], theta1[0])
          preds_hyper[k][j] = RevStdTheta1_hyper

      # Calculate performance and send to norm_error
      norm_error[k] = np.linalg.norm(preds_hyper[k] - np_gdp_ft[:,0][-hyperpar_testperiod:])

    lamda = lamda_set[np.argmin(norm_error)]
    # lamda = 0.001

    print("Hyperparamater Tuning Completed. Selected Lamda = ", lamda)
    print()

  # -------- RE-FITTING JM MODEL (Yizhan Shu, et al.) -----------

  if (i%n == 0):
    np_gdp_ft_std = Standardize(np_gdp_ft)
    theta0, theta1, s_new, V = JM(np_gdp_ft_std, lamda)

    if (i == 0):
      plt.plot(df_gdp_ft_train.index,s_new)
      plt.xlabel('Year')
      plt.ylabel('Recession')
      plt.title('Jump Model Optimal State Sequence for First Run')

  # ---------------- TRAINING PHASE {(x_t, s_t+1)} ----------------

  # Preparing Dataset to Train (Retrain every period; np_gdp_ft and s_new updates)
  data_train_x = np_gdp_ft_std[:-1]
  data_train_s_t1 = s_new[1:]

  # Train with XGBClassifier
  bst = XGBClassifier()
  bst.fit(data_train_x, data_train_s_t1)

  # ---------------------- FORECASTING PHASE ----------------------    
  sPred = bst.predict([np_gdp_ft_std[-1]])
  sPreds[i] = sPred[0]

  if (sPred[0] == 0):
    RevStdTheta0 = ReverseStandardize(np_gdp_ft, theta0[0])
    preds[i] = RevStdTheta0

  if (sPred[0] == 1):
    RevStdTheta1 = ReverseStandardize(np_gdp_ft, theta1[0])
    preds[i] = RevStdTheta1

  if (i == len(data_test_x)-2):
    print(V)

  # -------------------- PREPARE FOR NEXT ITERATION --------------------
    
  np_gdp_ft_retrain = np.vstack((np_gdp_ft_retrain, data_test_x[i]))
  np_gdp_ft = np_gdp_ft_retrain.copy()
# Out:
# 0
# Hyperparamater Tuning In Progress..
# Running trial on lamda =  0.0009765624999999987
# Running trial on lamda =  0.0065695032441696385
# Running trial on lamda =  0.044194173824159196
# Running trial on lamda =  0.2973017787506802
# Running trial on lamda =  2.0000000000000004
# Hyperparamater Tuning Completed. Selected Lamda =  2.0000000000000004
#
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 1
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 2
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 3
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 4
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 5
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 6
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 7
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 8
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 9
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 10
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 11
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 12
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.989625847320454
# 0.0
# Total Iterations:  3
# 13
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 14
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 15
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 16
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 17
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 18
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 19
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 20
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 21
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 22
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 23
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.962862846281368
# 0.0
# Total Iterations:  3
# 24
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.4624728081317357
# 0.0
# Total Iterations:  3
# 25
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 3.755512627586654
# 0.057638944538538794
# 0.0
# Total Iterations:  4
# 26
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 3.725506150271798
# 0.05027792809303833
# 0.0
# Total Iterations:  4
# 27
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 3.706266581153983
# 0.047334809567374236
# 0.0
# Total Iterations:  4
# 28
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 29
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.6546612085180072
# 0.0
# Total Iterations:  3
# 30
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.6552742611589792
# 0.0
# Total Iterations:  3
# 31
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.657248661258407
# 0.0
# Total Iterations:  3
# 32
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.663373307481635
# 0.0
# Total Iterations:  3
# 33
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.6701977650031523
# 0.0
# Total Iterations:  3
# 34
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.678411966351419
# 0.0
# Total Iterations:  3
# 35
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 36
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 2.695131849535713
# 0.0
# Total Iterations:  3
# 37
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 38
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 39
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 40
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 41
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 42
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 43
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 44
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# 45
# Objective Value Convergence per Iteration (lamda =  2.0000000000000004 )
# 100000
# 0.0
# Total Iterations:  2
# [[  2.39904416   1.31353835]
#  [  4.48737901   2.3694347 ]
#  [  6.40159639   3.39748021]
#  [  7.21821194   4.22955978]
#  [  7.94061425   4.89778902]
#  [  8.60754728   5.50239837]
#  [  9.22917154   6.08035912]
#  [  9.68995479   6.57756462]
#  [ 10.13851497   7.02053839]
#  [ 10.51155318   7.50253656]
#  [ 10.92900089   7.91927902]
#  [ 11.32220796   8.35969731]
#  [ 11.7351993    8.78828797]
#  [ 12.09198824   9.20467116]
#  [ 12.38255845   9.53370283]
#  [ 12.85831703   9.79631061]
#  [ 13.05639492  10.03139095]
#  [ 13.33385555  10.28828566]
#  [ 13.70254562  10.56956783]
#  [ 14.00569007  10.87414238]
#  [ 14.38644742  11.18296199]
#  [ 14.46562849  11.48426328]
#  [ 14.7460419   11.79656033]
#  [ 14.97853157  12.19598976]
#  [ 15.37263846  13.62464201]
#  [ 16.4049183   15.41523838]
#  [ 17.5182518   17.3601977 ]
#  [ 18.54795122  19.24242661]
#  [ 19.66793248  21.14310085]
#  [ 20.95216977  23.24208398]
#  [ 22.00885328  24.57811393]
#  [ 23.09573964  25.24325805]
#  [ 24.251239    26.07712362]
#  [ 25.61755292  26.99488695]
#  [ 26.94874823  27.82782787]
#  [ 28.39184288  28.59392015]
#  [ 29.93980274  29.39821426]
#  [ 31.49506844  30.11087675]
#  [ 33.09542716  30.59734365]
#  [ 34.2420072   30.99472982]
#  [ 34.4472573   31.27600318]
#  [ 34.88987775  31.55376802]
#  [ 35.09801303  31.80381138]
#  [ 35.1650845   32.10471726]
#  [ 35.52377219  32.37765998]
#  [ 35.82175928  32.6755288 ]
#  [ 36.10987254  33.0283539 ]
#  [ 36.414428    33.39069203]
#  [ 36.72314011  33.68099116]
#  [ 37.06198761  33.97765444]
#  [ 37.3850474   34.29959156]
#  [ 37.6290039   34.54748803]
#  [ 37.97975567  34.84336776]
#  [ 38.3441378   35.18529635]
#  [ 39.33420426  36.07051447]
#  [ 40.06814554  36.74060681]
#  [ 40.80979777  37.50874586]
#  [ 41.64531072  38.40496038]
#  [ 42.40010131  39.19724278]
#  [ 43.00611985  40.05619355]
#  [ 43.47136974  40.67694081]
#  [ 44.06710849  41.36987573]
#  [ 44.81246679  42.21793643]
#  [ 46.02648339  43.45193256]
#  [ 47.00881141  44.56998239]
#  [ 48.16429687  45.63829618]
#  [ 49.20038859  47.16699148]
#  [ 50.41244683  48.58747852]
#  [ 51.45281126  50.04007577]
#  [ 52.64748608  51.85227632]
#  [ 53.74618503  53.60593993]
#  [ 54.69417239  55.15909249]
#  [ 55.48198157  56.46994294]
#  [ 56.17471249  57.6827508 ]
#  [ 56.95108516  58.8962126 ]
#  [ 57.76027694  59.79870693]
#  [ 58.65016937  60.48961352]
#  [ 59.67564698  61.08446169]
#  [ 60.66697345  61.57070724]
#  [ 61.63147909  62.02761938]
#  [ 62.82099704  62.45362552]
#  [ 64.1174194   62.89376708]
#  [ 65.52611676  63.24837598]
#  [ 66.77591898  63.60723566]
#  [ 67.13477866  63.96609534]
#  [ 67.68271011  64.43556082]
#  [ 68.19917567  64.93755806]
#  [ 68.66360657  65.3629295 ]
#  [ 69.27800018  66.02019952]
#  [ 69.85962684  66.66144964]
#  [ 70.2671711   67.20127314]
#  [ 70.61793469  67.71557435]
#  [ 71.23295196  68.34135721]
#  [ 71.98233495  69.61423756]
#  [ 74.73141603  73.12565241]
#  [ 77.08962086  76.20405535]
#  [ 79.61896683  80.21100099]
#  [ 81.67374668  84.05782745]
#  [ 84.35491518  88.87113965]
#  [ 86.80643485  91.38099522]
#  [ 88.38421736  92.5425835 ]
#  [ 90.24198088  94.35031546]
#  [ 91.78278309  95.51107996]
#  [ 93.54106387  97.07111042]
#  [ 95.31071687  98.51436147]
#  [ 98.05325332 100.96432173]
#  [100.35519101 102.68010447]
#  [102.68503302 104.63684343]
#  [105.01008132 106.44051677]
#  [107.39601776 108.34796529]
#  [109.73337523 109.99830269]
#  [111.72863947 111.27515014]
#  [113.53441622 112.22823739]
#  [115.07360739 112.90592926]
#  [116.49373803 113.54053992]
#  [117.15988539 114.06446963]
#  [117.76818012 114.61258664]
#  [118.21443637 115.05576462]
#  [118.5817537  115.47584398]
#  [118.79925883 115.82933851]
#  [119.13361676 116.13181572]
#  [119.4249977  116.41432229]
#  [119.79910275 116.7322154 ]
#  [120.22885791 117.1039349 ]
#  [120.55067541 117.47984059]
#  [120.97373992 117.82320262]
#  [121.41534248 118.23021558]
#  [121.98803872 118.6939531 ]
#  [122.36517952 119.13967993]]

# %%
plt.figure(figsize=(12, 6))
plt.title('GDP Quarterly Forecast',fontsize='20')
plt.plot(df_gdp_ft_test[1:].index, preds[:])
plt.plot(df_gdp_ft_test[1:].index, data_test_x[1:,0])
y_min, y_max = plt.ylim()
plt.fill_between(df_gdp_ft_test[1:].index, 
                 y_min, y_max,
                 where=sPreds == 1, 
                 color='blue', alpha=0.13)
plt.text(df_gdp_ft_test[1:].index[-1],
         y_min + (y_max - y_min) * 0.05,
         'Blue Shaded Region: Forecasted Recessionary State',
         color='blue', 
         ha='right',
         va='bottom', 
         fontsize=12, 
         fontweight='bold', 
         alpha=0.5)
plt.legend(('Prediction', 'Actual'))
plt.ylabel('% Change in GDP Output')
plt.xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
print('2-Norm Error: ', np.linalg.norm(preds[:] - data_test_x[1:,0]))
# Out:
# 2-Norm Error:  4.448724823642823
